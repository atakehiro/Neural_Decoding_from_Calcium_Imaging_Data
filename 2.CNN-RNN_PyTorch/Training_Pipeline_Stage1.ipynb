# %% [markdown]
# Copyright 2021 Takehiro Ajioka

# %% [markdown]
# ### Enviroment
#
# Python 3.6
# Anaconda
# pytorch==1.9.0_cuda11.1
# fastai==2.5.2
# tifffile==2020.9.3
# opencv-python==4.5.3.56
# efficientnet-pytorch==0.7.1
# tqdm==4.47.0

# %% [markdown]
# # Stage1 Training

# %%
from fastai_stage1_training_efficientnet import stage1_train

# %%
import itertools
l = [1, 2, 3, 4, 5]
for v in itertools.permutations(l, 2):
    TRAIN = [i for i in l if i not in v]
    VALID = [v[0]]
    TEST = [v[1]]
    stage1_train(TRAIN, VALID, TEST)
# Out:
# [345]
# 1
# 2
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.125836</td>
#       <td>0.742444</td>
#       <td>09:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.079597</td>
#       <td>1.082018</td>
#       <td>09:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.040413</td>
#       <td>1.505875</td>
#       <td>09:08</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.7424435019493103.
# [245]
# 1
# 3
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130027</td>
#       <td>0.770795</td>
#       <td>08:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.081109</td>
#       <td>1.059405</td>
#       <td>08:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.042117</td>
#       <td>1.313222</td>
#       <td>08:52</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.770795464515686.
# [235]
# 1
# 4
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.125417</td>
#       <td>0.608843</td>
#       <td>08:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.076573</td>
#       <td>0.765731</td>
#       <td>08:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.037783</td>
#       <td>1.079763</td>
#       <td>08:38</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.6088432669639587.
# [234]
# 1
# 5
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.116114</td>
#       <td>0.972495</td>
#       <td>09:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.068536</td>
#       <td>1.280260</td>
#       <td>09:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.033702</td>
#       <td>1.607014</td>
#       <td>09:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.9724948406219482.
# [345]
# 2
# 1
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.125764</td>
#       <td>0.528587</td>
#       <td>09:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.079549</td>
#       <td>0.721056</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.040247</td>
#       <td>0.992214</td>
#       <td>09:22</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.5285866856575012.
# [145]
# 2
# 3
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.142362</td>
#       <td>0.476648</td>
#       <td>08:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.090976</td>
#       <td>0.448699</td>
#       <td>08:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.049117</td>
#       <td>0.735127</td>
#       <td>08:45</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.47664836049079895.
# Better model found at epoch 1 with valid_loss value: 0.4486989378929138.
# [135]
# 2
# 4
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.135291</td>
#       <td>0.444110</td>
#       <td>08:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.089318</td>
#       <td>0.553689</td>
#       <td>08:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.046511</td>
#       <td>0.710655</td>
#       <td>08:29</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.4441095292568207.
# [134]
# 2
# 5
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.132161</td>
#       <td>0.367975</td>
#       <td>09:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.080706</td>
#       <td>0.473301</td>
#       <td>09:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.043698</td>
#       <td>0.678532</td>
#       <td>09:06</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.36797499656677246.
# [245]
# 3
# 1
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130027</td>
#       <td>0.331651</td>
#       <td>09:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.081109</td>
#       <td>0.376949</td>
#       <td>09:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.042117</td>
#       <td>0.484590</td>
#       <td>09:00</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.33165061473846436.
# [145]
# 3
# 2
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.142362</td>
#       <td>0.325172</td>
#       <td>08:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.090976</td>
#       <td>0.345125</td>
#       <td>08:48</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.049117</td>
#       <td>0.469091</td>
#       <td>08:47</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.32517167925834656.
# [125]
# 3
# 4
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.140155</td>
#       <td>0.284525</td>
#       <td>08:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.088198</td>
#       <td>0.383643</td>
#       <td>08:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.043624</td>
#       <td>0.446099</td>
#       <td>08:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.2845247685909271.
# [124]
# 3
# 5
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.132877</td>
#       <td>0.295500</td>
#       <td>08:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.081152</td>
#       <td>0.352453</td>
#       <td>08:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.041229</td>
#       <td>0.467529</td>
#       <td>08:48</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.29550039768218994.
# [235]
# 4
# 1
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.125417</td>
#       <td>0.299682</td>
#       <td>08:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.076573</td>
#       <td>0.423975</td>
#       <td>08:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.037783</td>
#       <td>0.576450</td>
#       <td>08:52</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.29968154430389404.
# [135]
# 4
# 2
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.135291</td>
#       <td>0.373437</td>
#       <td>08:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.089318</td>
#       <td>0.391815</td>
#       <td>08:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.046511</td>
#       <td>0.663740</td>
#       <td>08:38</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.37343737483024597.
# [125]
# 4
# 3
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.140155</td>
#       <td>0.313046</td>
#       <td>08:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.088198</td>
#       <td>0.387023</td>
#       <td>08:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.043624</td>
#       <td>0.586614</td>
#       <td>08:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.31304553151130676.
# [123]
# 4
# 5
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.127200</td>
#       <td>0.394796</td>
#       <td>08:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.077527</td>
#       <td>0.452588</td>
#       <td>08:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.037954</td>
#       <td>0.563776</td>
#       <td>08:38</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3947955071926117.
# [234]
# 5
# 1
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.116114</td>
#       <td>0.323352</td>
#       <td>09:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.068536</td>
#       <td>0.340047</td>
#       <td>09:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.033702</td>
#       <td>0.401135</td>
#       <td>09:18</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3233523368835449.
# [134]
# 5
# 2
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.132161</td>
#       <td>0.231209</td>
#       <td>09:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.080706</td>
#       <td>0.281255</td>
#       <td>09:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.043698</td>
#       <td>0.388541</td>
#       <td>09:06</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.2312094122171402.
# [124]
# 5
# 3
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.132877</td>
#       <td>0.269486</td>
#       <td>08:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.081152</td>
#       <td>0.355259</td>
#       <td>08:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.041229</td>
#       <td>0.445407</td>
#       <td>08:43</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.26948580145835876.
# [123]
# 5
# 4
# Loaded pretrained weights for efficientnet-b0
# 4008829
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.127200</td>
#       <td>0.373299</td>
#       <td>08:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.077527</td>
#       <td>0.396493</td>
#       <td>08:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.037954</td>
#       <td>0.534824</td>
#       <td>08:28</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3732987344264984.
